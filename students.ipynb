# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df2= pd.read_csv("Expanded_data_with_more_features.csv");
print(df2.head())
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
df2.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %%
df2.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
#Gender distribution
plt.figure(figsize=(3,2))
ax=sns.countplot(data=df,x="Gender")
ax.bar_label(ax.containers[0]);
plt.title("Gender Distribution")
plt.show()

# %%
par=df.groupby("ParentEduc").agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
print(par)
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.527787     71.368350     70.374619
# bachelor's degree   70.635000     73.375556     73.423611
# high school         64.670038     67.522467     65.565909
# master's degree     72.168137     75.202044     75.246168
# some college        66.603434     69.528093     68.653661
# some high school    62.926359     65.826816     63.815473

# %%
plt.figure(figsize=(4,4))
sns.heatmap(par,annot=True)
plt.title("Parent's Education and Score")
plt.show()

# %%
par=df2.groupby("ParentMaritalStatus").agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})
print(par)
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
plt.figure(figsize=(4,4))
sns.heatmap(par,annot=True)
plt.title("Parent's Marital Status and Score")
plt.show()

# %%
sns.boxplot(data=df2,x="MathScore");
plt.show()

# %%
sns.boxplot(data=df2,x="ReadingScore");
plt.show()

# %%
print(df2["EthnicGroup"].unique())
# Out:
# [nan 'group C' 'group B' 'group A' 'group D' 'group E']

# %%
groupA=df2.loc[(df2['EthnicGroup']=="group A")].count()
groupB=df2.loc[(df2['EthnicGroup']=="group B")].count()
groupC=df2.loc[(df2['EthnicGroup']=="group C")].count()
groupD=df2.loc[(df2['EthnicGroup']=="group D")].count()
groupE=df2.loc[(df2['EthnicGroup']=="group E")].count()
l=["group A","group B","group C","group D","group E"]
mlist=[groupA["EthnicGroup"],groupB["EthnicGroup"],groupC["EthnicGroup"],groupD["EthnicGroup"],groupE["EthnicGroup"]]
plt.pie(mlist, labels = l,autopct="%1.2f%%")
plt.title("Distribution of Ethnic Groups")
plt.show()

# %%
ax=sns.countplot(data=df,x="EthnicGroup")
ax.bar_label(ax.containers[0]);
plt.title("Ethnic Groups Distribution")
plt.show()

# %%
transport_counts = df2['TransportMeans'].value_counts()
plt.pie(transport_counts, labels=transport_counts.index, autopct='%1.1f%%')
plt.title("Distribution of Transport")
plt.show()

# %%
sorted_counts = df2['PracticeSport'].value_counts()
ax = sns.countplot(data=df2, x="PracticeSport", order=sorted_counts.index)
plt.title("Sports in decreasing order")
plt.ylabel("Count")
plt.show()
#displays in sorted order

# %%
df2[['MathScore', 'ReadingScore', 'WritingScore']].hist(bins=20, figsize=(10, 6))
plt.suptitle("Histograms of Scores")
plt.show()

# %%
transport_counts = df2['NrSiblings'].value_counts()
plt.pie(transport_counts, labels=transport_counts.index, autopct='%1.1f%%')
plt.title("Number of siblings for students")
plt.show()
